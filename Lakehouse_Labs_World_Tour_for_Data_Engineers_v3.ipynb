# %% [markdown]
# # Lakehouse Labs World Tour for Data Engineers
# Welcome to the Data and AI World Tour for data engineers.  Over the course of this notebook, you will use an open dataset and learn how to:
# 1. Ingest data that has been landed into cloud storage
# 2. Transform and store your data in the reliable and performant Delta Lake storage format
# 3. Use Update, Delete, Merge, Schema Evolution, Time Travel Capabilities, and CDF (Change Data Feed) functionality built in the Delta Lake storage format
#
# ## The Use Case
# We will analyze United States zip code data that is made available as a public dataset online. You can learn more about the dataset [here](https://simplemaps.com/data/us-zips), but we'll download it automatically below.

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
# %sql
set spark.databricks.delta.properties.defaults.enableChangeDataFeed = true;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th></tr></thead><tbody><tr><td>spark.databricks.delta.properties.defaults.enableChangeDataFeed</td><td>true</td></tr></tbody></table></div>

# %%
# %sh
# Pull CSV file from url
wget -nc https://lafkkbox.blob.core.windows.net/worldtourdata/uszips.csv

# Move from databricks/driver to dbfs
mv /databricks/driver/uszips.csv /dbfs/FileStore/uszips.csv
# Out:
# --2022-10-18 13:49:35--  https://lafkkbox.blob.core.windows.net/worldtourdata/uszips.csv
# Resolving lafkkbox.blob.core.windows.net (lafkkbox.blob.core.windows.net)... 20.60.59.235
# Connecting to lafkkbox.blob.core.windows.net (lafkkbox.blob.core.windows.net)|20.60.59.235|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6323670 (6.0M) [text/csv]
# Saving to: ‘uszips.csv’
#
#      0K .......... .......... .......... .......... ..........  0% 1.07M 6s
#     50K .......... .......... .......... .......... ..........  1% 2.12M 4s
#    100K .......... .......... .......... .......... ..........  2% 2.13M 4s
#    150K .......... .......... .......... .......... ..........  3% 2.11M 3s
#    200K .......... .......... .......... .......... ..........  4%  198M 3s
#    250K .......... .......... .......... .......... ..........  4% 2.15M 3s
#    300K .......... .......... .......... .......... ..........  5%  157M 2s
#    350K .......... .......... .......... .......... ..........  6% 2.16M 2s
#    400K .......... .......... .......... .......... ..........  7%  164M 2s
#    450K .......... .......... .......... .......... ..........  8%  169M 2s
#    500K .......... .......... .......... .......... ..........  8% 2.21M 2s
#    550K .......... .......... .......... .......... ..........  9% 91.3M 2s
#    600K .......... .......... .......... .......... .......... 10%  133M 2s
#    650K .......... .......... .......... .......... .......... 11%  193M 1s
#    700K .......... .......... .......... .......... .......... 12%  153M 1s
#    750K .......... .......... .......... .......... .......... 12% 2.24M 1s
#    800K .......... .......... .......... .......... .......... 13%  109M 1s
#    850K .......... .......... .......... .......... .......... 14%  156M 1s
#    900K .......... .......... .......... .......... .......... 15%  171M 1s
#    950K .......... .......... .......... .......... .......... 16%  165M 1s
#   1000K .......... .......... .......... .......... .......... 17%  179M 1s
#   1050K .......... .......... .......... .......... .......... 17% 2.29M 1s
#   1100K .......... .......... .......... .......... .......... 18%  140M 1s
#   1150K .......... .......... .......... .......... .......... 19%  129M 1s
#   1200K .......... .......... .......... .......... .......... 20%  169M 1s
#   1250K .......... .......... .......... .......... .......... 21%  181M 1s
#   1300K .......... .......... .......... .......... .......... 21%  162M 1s
#   1350K .......... .......... .......... .......... .......... 22%  125M 1s
#   1400K .......... .......... .......... .......... .......... 23%  183M 1s
#dbutils.fs.mv("file:/databricks/driver/uszips.csv", "dbfs:/FileStore/uszips.csv", recurse=True)
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# <command-4367306520264190> in <cell line: 1>()
# ----> 1 dbutils.fs.mv("file:/databricks/driver/uszips.csv", "dbfs:/FileStore/uszips.csv", recurse=True)
#
# /databricks/python_shell/dbruntime/dbutils.py in f_with_exception_handling(*args, **kwargs)
#     388                     exc.__context__ = None
#     389                     exc.__cause__ = None
# --> 390                     raise exc
#     391
#     392             return f_with_exception_handling
#
# ExecutionError: An error occurred while calling o464.mv.
# : java.io.FileNotFoundException: File file:/databricks/driver/uszips.csv does not exist
# 	at org.apache.hadoop.fs.RawLocalFileSystem.deprecatedGetFileStatus(RawLocalFileSystem.java:779)
# 	at org.apache.hadoop.fs.RawLocalFileSystem.getFileLinkStatusInternal(RawLocalFileSystem.java:1100)
# 	at org.apache.hadoop.fs.RawLocalFileSystem.getFileStatus(RawLocalFileSystem.java:769)
# 	at org.apache.hadoop.fs.FilterFileSystem.getFileStatus(FilterFileSystem.java:462)
# 	at com.databricks.backend.daemon.driver.WorkspaceLocalFileSystem.super$getFileStatus(WorkspaceLocalFileSystem.scala:75)
# 	at com.databricks.backend.daemon.driver.WorkspaceLocalFileSystem.$anonfun$getFileStatus$1(WorkspaceLocalFileSystem.scala:75)
# 	at com.databricks.backend.daemon.driver.WorkspaceLocalFileSystem.$anonfun$getFileStatus$1$adapted(WorkspaceLocalFileSystem.scala:74)
# 	at com.databricks.backend.daemon.driver.WSFSCredentialForwardingHelper.$anonfun$withWSFSCredentials$1(WorkspaceLocalFileSystem.scala:215)
# 	at com.databricks.backend.daemon.driver.WSFSCredentialForwardingHelper.withWSFSCredentials(WorkspaceLocalFileSystem.scala:186)
# 	at com.databricks.backend.daemon.driver.WSFSCredentialForwardingHelper.withWSFSCredentials(WorkspaceLocalFileSystem.scala:215)
# 	at com.databricks.backend.daemon.driver.WSFSCredentialForwardingHelper.withWSFSCredentials$(WorkspaceLocalFileSystem.scala:213)
# 	at com.databricks.backend.daemon.driver.WorkspaceLocalFileSystem.withWSFSCredentials(WorkspaceLocalFileSystem.scala:32)
# 	at com.databricks.backend.daemon.driver.WorkspaceLocalFileSystem.getFileStatus(WorkspaceLocalFileSystem.scala:74)
# 	at com.databricks.backend.daemon.dbutils.FSUtils.$anonfun$withMvSafetyChecks$2(DBUtilsCore.scala:178)
# 	at com.databricks.backend.daemon.dbutils.FSUtils.withFsSafetyCheck(DBUtilsCore.scala:142)
# 	at com.databricks.backend.daemon.dbutils.FSUtils.$anonfun$withMvSafetyChecks$1(DBUtilsCore.scala:174)
# 	at com.databricks.backend.daemon.dbutils.FSUtils.withFsSafetyCheck(DBUtilsCore.scala:142)
# 	at com.databricks.backend.daemon.dbutils.FSUtils.withMvSafetyChecks(DBUtilsCore.scala:174)
# 	at com.databricks.backend.daemon.dbutils.FSUtils.$anonfun$mv$2(DBUtilsCore.scala:345)
# 	at com.databricks.backend.daemon.dbutils.FSUtils.checkPermission(DBUtilsCore.scala:137)
# 	at com.databricks.backend.daemon.dbutils.FSUtils.$anonfun$mv$1(DBUtilsCore.scala:345)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:515)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:609)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:630)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:377)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:108)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:375)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:372)
# 	at com.databricks.backend.daemon.dbutils.FSUtils.withAttributionContext(DBUtilsCore.scala:66)
# 	at com.databricks.logging.UsageLogging.withAttributionTags(UsageLogging.scala:420)
# 	at com.databricks.logging.UsageLogging.withAttributionTags$(UsageLogging.scala:405)
# 	at com.databricks.backend.daemon.dbutils.FSUtils.withAttributionTags(DBUtilsCore.scala:66)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:604)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:524)
# 	at com.databricks.backend.daemon.dbutils.FSUtils.recordOperationWithResultTags(DBUtilsCore.scala:66)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:515)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:487)
# 	at com.databricks.backend.daemon.dbutils.FSUtils.recordOperation(DBUtilsCore.scala:66)
# 	at com.databricks.backend.daemon.dbutils.FSUtils
quot;,&quot;PR&quot;,&quot;Puerto Rico&quot;,&quot;TRUE&quot;,&quot;&quot;,&quot;22383&quot;,&quot;250.9&quot;,&quot;72121&quot;,&quot;Sabana Grande&quot;,&quot;{&quot;&quot;72121&quot;&quot;: &quot;&quot;99.56&quot;&quot;, &quot;&quot;72153&quot;&quot;: &quot;&quot;0.44&quot;&quot;}&quot;,&quot;Sabana Grande|Yauco&quot;,&quot;72121|72153&quot;,&quot;FALSE&quot;,&quot;FALSE&quot;,&quot;America/Puerto_Rico&quot;
# &quot;00638&quot;,&quot;18.28905&quot;,&quot;-66.5151&quot;,&quot;Ciales&quot;,&quot;PR&quot;,&quot;Puerto Rico&quot;,&quot;TRUE&quot;,&quot;&quot;,&quot;16412&quot;,&quot;95.9&quot;,&quot;72039&quot;,&quot;Ciales&quot;,&quot;{&quot;&quot;72039&quot;&quot;: &quot;&quot;98.27&quot;&quot;, &quot;&quot;72091&quot;&quot;: &quot;&quot;1.73&quot;&quot;}&quot;,&quot;Ciales|Manatí&quot;,&quot;72039|72091&quot;,&quot;FALSE&quot;,&quot;FALSE&quot;,&quot;America/Puerto_Rico&quot;
# &quot;00641&quot;,&quot;18.26408&quot;,&quot;-66.71376&quot;,&quot;Utuado&quot;,&quot;PR&quot;,&quot;Puerto Rico&quot;,&quot;TRUE&quot;,&quot;&quot;,&quot;26712&quot;,&quot;110.3&quot;,&quot;72141&quot;,&quot;Utuado&quot;,&quot;{&quot;&quot;72141&quot;&quot;: &quot;&quot;99.79&quot;&quot;, &quot;&quot;72001&quot;&quot;: &quot;&quot;0.21&quot;&quot;}&quot;,&quot;Utuado|Adjuntas&quot;,&quot;72141|72001&quot;

# %%
# CSV schema
schema = "zip string,lat double,lng double,city string,state_id string,state_name string,zcta boolean,parent_zcta string,population integer,density double,county_fips integer,county_name string,county_weights string,county_names_all string,county_fips_all string,imprecise boolean,military boolean,timezone string"

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format("csv") \
  .option("header", "true") \
  .option("sep", ",") \
  .option("escape", "\"") \
  .schema(schema) \
  .load("dbfs:/FileStore")

display(df)

# write data out in Delta format
# we'll skip writing this data for now as we'll use another ingestion pattern
# df.write.format("delta").partitionBy('state_id').save('/mnt/delta/uszips_delta')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>zip</th><th>lat</th><th>lng</th><th>city</th><th>state_id</th><th>state_name</th><th>zcta</th><th>parent_zcta</th><th>population</th><th>density</th><th>county_fips</th><th>county_name</th><th>county_weights</th><th>county_names_all</th><th>county_fips_all</th><th>imprecise</th><th>military</th><th>timezone</th></tr></thead><tbody><tr><td>00601</td><td>18.18005</td><td>-66.75218</td><td>Adjuntas</td><td>PR</td><td>Puerto Rico</td><td>true</td><td>null</td><td>17113</td><td>102.7</td><td>72001</td><td>Adjuntas</td><td>{"72001": "99.43", "72141": "0.57"}</td><td>Adjuntas|Utuado</td><td>72001|72141</td><td>false</td><td>false</td><td>America/Puerto_Rico</td></tr><tr><td>00602</td><td>18.36074</td><td>-67.17519</td><td>Aguada</td><td>PR</td><td>Puerto Rico</td><td>true</td><td>null</td><td>37751</td><td>476.0</td><td>72003</td><td>Aguada</td><td>{"72003": "100"}</td><td>Aguada</td><td>72003</td><td>false</td><td>false</td><td>America/Puerto_Rico</td></tr><tr><td>00603</td><td>18.4544</td><td>-67.12201</td><td>Aguadilla</td><td>PR</td><td>Puerto Rico</td><td>true</td><td>null</td><td>47081</td><td>574.9</td><td>72005</td><td>Aguadilla</td><td>{"72005": "100"}</td><td>Aguadilla</td><td>72005</td><td>false</td><td>false</td><td>America/Puerto_Rico</td></tr><tr><td>00606</td><td>18.16721</td><td>-66.93828</td><td>Maricao</td><td>PR</td><td>Puerto Rico</td><td>true</td><td>null</td><td>6392</td><td>58.3</td><td>72093</td><td>Maricao</td><td>{"72093": "94.88", "72153": "3.78", "72121": "1.35"}</td><td>Maricao|Yauco|Sabana Grande</td><td>72093|72153|72121</td><td>false</td><td>false</td><td>America/Puerto_Rico</td></tr><tr><td>00610</td><td>18.29032</td><td>-67.12244</td><td>Anasco</td><td>PR</td><td>Puerto Rico</td><td>true</td><td>null</td><td>26686</td><td>286.9</td><td>72011</td><td>Añasco</td><td>{"72011": "99.45", "72003": "0.55"}</td><td>Añasco|Aguada</td><td>72011|72003</td><td>false</td><td>false</td><td>America/Puerto_Rico</td></tr><tr><td>00612</td><td>18.40699</td><td>-66.70805</td><td>Arecibo</td><td>PR</td><td>Puerto Rico</td><td>true</td><td>null</td><td>59369</td><td>339.1</td><td>72013</td><td>Arecibo</td><td>{"72013": "99.89", "72017": "0.11"}</td><td>Arecibo|Barceloneta</td><td>72013|72017</td><td>false</td><td>false</td><td>America/Puerto_Rico</td></tr><tr><td>00616</td><td>18.41752</td><td>-66.66814</td><td>Bajadero</td><td>PR</td><td>Puerto Rico</td><td>true</td><td>null</td><td>10022</td><td>335.6</td><td>72013</td><td>Arecibo</td><td>{"72013": "100"}</td><td>Arecibo</td><td>72013</td><td>false</td><td>false</td><td>America/Puerto_Rico</td></tr><tr><td>00617</td><td>18.44125</td><td>-66.55916</td><td>Barceloneta</td><td>PR</td><td>Puerto Rico</td><td>true</td><td>null</td><td>23750</td><td>603.5</td><td>72017</td><td>Barceloneta</td><td>{"72017": "99.43", "72054": "0.57"}</td><td>Barceloneta|Florida</td><td>72017|72054</td><td>false</td><td>false</td><td>America/Puerto_Rico</td></tr><tr><td>00622</td><td>17.99174</td><td>-67.15248</td><td>Boqueron</td><td>PR</td><td>Puerto Rico</td><td>true</td><td>null</td><td>6741</td><td>89.8</td><td>72023</td><td>Cabo Rojo</td><td>{"72023": "100"}</td><td>Cabo Rojo</td><td>72023</td><td>false</td><td>false</td><td>America/Puerto_Rico</td></tr><tr><td>00623</td><td>18.08354</td><td>-67.15418</td><td>Cabo Rojo</td><td>PR</td><td>Puerto Rico</td><td>true</td><td>null</td><td>41746</td><td>424.5</td><td>72023</td><td>Cabo Rojo</td><td>{"72023": "100"}</td><td>Cabo Rojo</td><td>72023</td><td>false</td><td>false</td><td>America/Puerto_Rico</td></tr><tr><td>00624</td><td>18.06465</td><td>-66.71823</td><td>Penuelas</td><td>PR</td><td>Puerto Rico</td><td>true</td><td>null</td><td>21936</td><td>196.2</td><td>72111</td><td>Peñuelas</td><td>{"72111": "92.53", "72113": "7.47"}</td><td>Peñuelas|Ponce</td><td>72111|72113</td><td>false</td><td>false</td><td>America/Puerto_Rico ...

# %% [markdown]
# <!-- #DATA ENGINEERING AND STREAMING ARCHITECTURE -->
# <img src="https://publicimg.blob.core.windows.net/images/DE and Streaming2.png" width="1200">

# %% [markdown]
# ####Auto Loader, COPY INTO, and Incrementally Ingesting Data
# [Auto Loader](https://docs.databricks.com/spark/latest/structured-streaming/auto-loader-gen2.html) and [COPY INTO](https://docs.databricks.com/ingestion/copy-into/index.html) are two methods of ingesting data into a Delta Lake table from a folder in a Data Lake. “Yeah, so... Why is that so special?”, you may ask. The reason these features are special is that they make it possible to ingest data directly from a data lake incrementally, in an idempotent way, without needing a distributed streaming system like Kafka. This can considerably simplify the Incremental ETL process. It is also an extremely efficient way to ingest data since you are only ingesting new data and not reprocessing data that already exists. Below is an Incremental ETL architecture. We will focus on the left hand side, ingesting into tables from outside sources.
#
# You can incrementally ingest data either continuously or scheduled in a job. COPY INTO and Auto Loader cover both cases and we will show you how below.
#
# <img src="https://databricks.com/wp-content/uploads/2021/07/get-start-delta-blog-img-1.png" width=1000>

# %% [markdown]
# ### Autoloader
# In this notebook we will use Auto Loader for a basic ingest use case with [schema inference and evolution](https://docs.databricks.com/spark/latest/structured-streaming/auto-loader-gen2.html#schema-inference-and-evolution).
# Notice how the schema is inferred, but we can provide schema hints for certain columns also.

# %%
spark.sql("DROP DATABASE IF EXISTS population CASCADE")
dbutils.fs.rm("/mnt/delta/", recurse=True)
spark.sql("CREATE DATABASE IF NOT EXISTS population LOCATION '/mnt/delta/'")
# Out:
# Out[5]: DataFrame[]

# %%
# "cloudFiles" indicates the use of Auto Loader

dfBronze = spark.readStream.format("cloudFiles") \
  .option('cloudFiles.format', 'csv') \
  .option('header','true') \
  .option("cloudFiles.schemaLocation", "/mnt/delta/checkpoint/uszips_delta/") \
  .option("cloudFiles.schemaHints", "zip string, population integer, density double") \
  .load("dbfs:/FileStore")

# The stream will shut itself off when it is finished based on the trigger once feature
# The checkpoint location saves the state of the ingest when it is shut off so we know where to pick up next time
# Notice that we can partition our data as well.  Partioning isn't recommended unless our data is over a GB in size.  Use Optimize and ZOrder instead which is explained below.
dfBronze.writeStream \
  .format("delta") \
  .partitionBy('state_id') \
  .trigger(once=True) \
  .option("checkpointLocation", "/mnt/delta/checkpoint/uszips_delta/") \
  .start("/mnt/delta/uszips_delta/")
# Out:
# Out[13]: <pyspark.sql.streaming.query.StreamingQuery at 0x7f0b9ce6eaf0>

# %%
# %sql
CREATE TABLE IF NOT EXISTS population.uszips
 
USING DELTA 
LOCATION '/mnt/delta/uszips_delta/'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
DESCRIBE EXTENDED population.uszips
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>zip</td><td>string</td><td>null</td></tr><tr><td>lat</td><td>string</td><td>null</td></tr><tr><td>lng</td><td>string</td><td>null</td></tr><tr><td>city</td><td>string</td><td>null</td></tr><tr><td>state_id</td><td>string</td><td>null</td></tr><tr><td>state_name</td><td>string</td><td>null</td></tr><tr><td>zcta</td><td>string</td><td>null</td></tr><tr><td>parent_zcta</td><td>string</td><td>null</td></tr><tr><td>population</td><td>int</td><td>null</td></tr><tr><td>density</td><td>double</td><td>null</td></tr><tr><td>county_fips</td><td>string</td><td>null</td></tr><tr><td>county_name</td><td>string</td><td>null</td></tr><tr><td>county_weights</td><td>string</td><td>null</td></tr><tr><td>county_names_all</td><td>string</td><td>null</td></tr><tr><td>county_fips_all</td><td>string</td><td>null</td></tr><tr><td>imprecise</td><td>string</td><td>null</td></tr><tr><td>military</td><td>string</td><td>null</td></tr><tr><td>timezone</td><td>string</td><td>null</td></tr><tr><td>_rescued_data</td><td>string</td><td>null</td></tr><tr><td># Partition Information</td><td></td><td></td></tr><tr><td># col_name</td><td>data_type</td><td>comment</td></tr><tr><td>state_id</td><td>string</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>spark_catalog</td><td></td></tr><tr><td>Database</td><td>population</td><td></td></tr><tr><td>Table</td><td>uszips</td><td></td></tr><tr><td>Type</td><td>EXTERNAL</td><td></td></tr><tr><td>Location</td><td>dbfs:/mnt/delta/uszips_delta</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Table Properties</td><td>[delta.enableChangeDataFeed=true,delta.minReaderVersion=1,delta.minWriterVersion=4]</td><td></td></tr></tbody></table></div>

# %%
# %fs ls "/mnt/delta/uszips_delta/"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/delta/uszips_delta/_delta_log/</td><td>_delta_log/</td><td>0</td><td>1665954226000</td></tr><tr><td>dbfs:/mnt/delta/uszips_delta/state_id=AK/</td><td>state_id=AK/</td><td>0</td><td>1665954208000</td></tr><tr><td>dbfs:/mnt/delta/uszips_delta/state_id=AL/</td><td>state_id=AL/</td><td>0</td><td>1665954211000</td></tr><tr><td>dbfs:/mnt/delta/uszips_delta/state_id=AR/</td><td>state_id=AR/</td><td>0</td><td>1665954211000</td></tr><tr><td>dbfs:/mnt/delta/uszips_delta/state_id=AS/</td><td>state_id=AS/</td><td>0</td><td>1665954211000</td></tr><tr><td>dbfs:/mnt/delta/uszips_delta/state_id=AZ/</td><td>state_id=AZ/</td><td>0</td><td>1665954212000</td></tr><tr><td>dbfs:/mnt/delta/uszips_delta/state_id=CA/</td><td>state_id=CA/</td><td>0</td><td>1665954212000</td></tr><tr><td>dbfs:/mnt/delta/uszips_delta/state_id=CO/</td><td>state_id=CO/</td><td>0</td><td>1665954212000</td></tr><tr><td>dbfs:/mnt/delta/uszips_delta/state_id
yder</td></tr><tr><td>MN</td><td>27003</td><td>Anoka</td></tr><tr><td>MN</td><td>27013</td><td>Blue Earth</td></tr><tr><td>NY</td><td>36043</td><td>Herkimer</td></tr><tr><td>IL</td><td>17165</td><td>Saline</td></tr><tr><td>CA</td><td>06113</td><td>Yolo</td></tr><tr><td>OH</td><td>39119</td><td>Muskingum</td></tr><tr><td>OH</td><td>39111</td><td>Monroe</td></tr><tr><td>MO</td><td>29007</td><td>Audrain</td></tr><tr><td>MO</td><td>29077</td><t ...

# %% [markdown]
# ###Creating Silver/Gold tables
# Create an aggregate table usign PySpark.  This could have also been done using SQL, Scala, or R.
# Notice that we're able to write the table to a Delta path and register the table in one line.

# %%
city_county_df = spark.read.format("delta").load("/mnt/delta/uszips_delta/") \
  .groupBy("state_id", "city", "county_fips").sum('population') \
  .withColumnRenamed("sum(population)", "populationSum")

city_county_df.write.format("delta").mode('overwrite').option('path', '/mnt/delta/city_delta/').saveAsTable('population.city')

# %%
# %sql
ALTER TABLE population.city SET TBLPROPERTIES (delta.enableChangeDataFeed=true)

# %%
# %sql
SELECT * FROM population.city

# %% [markdown]
# ### Perform DML operations, Schema Evolution and Time Travel
# #####Delta Lake supports standard DML including UPDATE, DELETE and MERGE INTO providing data engineers more controls to manage their big datasets.

# %% [markdown]
# ### DELETE Support

# %%
# %sql
DELETE FROM population.city WHERE populationSum <= 10000

# %%
# %sql
SELECT * FROM population.city WHERE populationSum <= 10000

# %% [markdown]
# ### UPDATE Support

# %%
# %sql
UPDATE population.city SET populationSum = 19999 WHERE populationSum BETWEEN 10000 AND 20000

# %%
# %sql
SELECT * FROM population.city WHERE populationSum BETWEEN 10000 AND 20000

# %% [markdown]
# ###MERGE Support
# We can merge directly into a Delta Lake table and perform Inserts, Updates, and Deletes in one simple statement.
# This is supported in multiple languages, but we'll perform the command in SQL.

# %% [markdown]
# ### Schema Evolution
# With the `autoMerge` option, you can evolve your Delta Lake table schema seamlessly inside the ETL pipeline. New columns will automatically be added to your table.

# %%
# %sql
set spark.databricks.delta.schema.autoMerge.enabled = true;

# %%
# %sql
-- Our CTE has a new column called densityAvg
WITH merge_cte AS (
SELECT state_id, city, county_fips, SUM(population) AS populationSum, AVG(density) AS densityAvg
FROM population.uszips
WHERE state_id <> 'OH'
GROUP BY state_id, city, county_fips
)

MERGE INTO population.city as d
USING merge_cte as m
on d.state_id = m.state_id AND d.city = m.city AND d.county_fips = m.county_fips
WHEN MATCHED THEN 
  UPDATE SET *
WHEN NOT MATCHED 
  THEN INSERT *

# %%
# %sql
--Notice our new column has been seamlessly added to the table
SELECT * FROM population.city WHERE populationSum <= 10000

# %%
# %sql
--Notice our new column has been seamlessly added to the table
SELECT * FROM population.city WHERE populationSum BETWEEN 10000 AND 20000

# %% [markdown]
# ###Let's travel back in time with Time Travel!
# Databricks Delta’s time travel capabilities simplify building data pipelines for the following use cases.
#
# * Audit Data Changes
# * Reproduce experiments & reports
# * Rollbacks
#
# As you write into a Delta table or directory, every operation is automatically versioned.
#
# You can query by:
# 1. Using a timestamp
# 1. Using a version number
#
# using Python, Scala, and/or Scala syntax; for these examples we will use the SQL syntax.
#
# For more information, refer to [Introducing Delta Time Travel for Large Scale Data Lakes](https://databricks.com/blog/2019/02/04/introducing-delta-time-travel-for-large-scale-data-lakes.html)

# %%
# %sql
DESCRIBE HISTORY population.city

# %% [markdown]
# ####  Time Travel via Version Number
# Below are SQL syntax examples of Delta Time Travel by using a Version Number

# %%
# %sql
SELECT * FROM population.city VERSION AS OF 2

# %% [markdown]
# ### We can even roll back a table to a previous version

# %%
# %sql
RESTORE TABLE population.city TO VERSION AS OF 2

# %%
# %sql
SELECT * FROM population.city

# %% [markdown]
# ### Or even create shallow or deep clones of a table (backups or testing tables)

# %%
# %sql
CREATE OR REPLACE TABLE population.city_bak
DEEP CLONE population.city
LOCATION '/mnt/delta/city_delta_bak'

# %%
# %sql
SELECT * FROM population.city_bak

# %% [markdown]
# ### Simplify Your Medallion Architecture with Delta Lake’s CDF Feature
#
# ### Overview
# The medallion architecture takes raw data landed from source systems and refines the data through bronze, silver and gold tables. It is an architecture that the MERGE operation and log versioning in Delta Lake make possible. Change data capture (CDC) is a use case that we see many customers implement in Databricks. The [Change Data Feed](https://docs.databricks.com/delta/delta-change-data-feed.html) (CDF) feature in Delta Lake makes this architecture even simpler to implement!
#
# CDF makes it possible to detect data changes between versions or timestamps of a Delta table. This allows us to build ETL pipelines that can be naturally incremental in nature. The CDF table_changes function lets us analyze the changes (inserts, updates, and deletes) that have occured on a Delta table which we can then use to funnel changes to downstream consumers.
#
# <img src="https://databricks.com/wp-content/uploads/2021/05/cdf-blog-img-1-rev.png" width=600>

# %%
# %fs ls '/mnt/delta/city_delta'

# %%
# %sql
SELECT * FROM table_changes('population.city', 1)

# %% [markdown]
# ### IDENTITY COLUMNS
# Delta Lake now supports identity columns. When you write to a Delta table that defines an identity column, and you do not provide values for that column, Delta automatically assigns a unique and statistically increasing or decreasing value.

# %%
# %sql
CREATE TABLE population.dim_states
( state_sk BIGINT GENERATED ALWAYS AS IDENTITY,
  state_id STRING, 
  state_name STRING
)
USING DELTA
LOCATION '/mnt/delta/dim_states_delta'

# %%
# %sql
INSERT INTO population.dim_states (state_id, state_name) 
SELECT * FROM population.states

# %%
# %sql
SELECT * FROM population.dim_states

# %% [markdown]
# #####  OPTIMIZE
# OPTIMIZE optimizes the layout of Delta Lake data. Optionally, optimize a subset of data or colocate data by column. If you do not specify colocation, bin-packing optimization is performed.

# %%
# %sql 
OPTIMIZE population.city ZORDER BY (state_id)

# %% [markdown]
# ###But Wait, There's Even More in Delta Lake!
# We've explored a lot of the awesome powers of the [Delta Lake](https://docs.databricks.com/delta/index.html) storage format, but there is even more capabilities that Delta Lake provides.
# Check the docs to explore even more functinality like:
# - Unified Batch and Streaming directly from Delta Lake tables
# - Constraints
# - Primary Keys and Foreign Keys
# - Information Schema views
# - Automatic capture of table statistics for data skipping
# - Computed/generated columns
